# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
import statsmodels.api as sm
import imblearn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-46-663e6328646a> in <module>
#       5 from sklearn.preprocessing import LabelEncoder
#       6 import statsmodels.api as sm
# ----> 7 import imblearn
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/imblearn/__init__.py in <module>
#      32     Module which allowing to create pipeline with scikit-learn estimators.
#      33 """
# ---> 34 from . import combine
#      35 from . import ensemble
#      36 from . import exceptions
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/imblearn/combine/__init__.py in <module>
#       3 """
#       4
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       7
#
# ...

# %%
def label_encode(col,df):
    label_encoder = LabelEncoder()
    df[col]=label_encoder.fit_transform(df[col])

# %%
data = pd.read_csv('data/train.csv')
X=data[['Agency','Agency Type','Distribution Channel','Product Name','Destination']]

for col in list(X):
    label_encode(col,X)
X.head()
y=data.Claim
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Since there is imbalance in target we need to do SMOTE. 
# imbalance is 0 >> 43590 and 1 >> 8720

smt = SMOTE()
X_train, y_train = smt.fit_sample(X, y)
np.bincount(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-5e5a1023e62b> in <module>
#       2 # imbalance is 0 >> 43590 and 1 >> 8720
#       3
# ----> 4 smt = SMOTE()
#       5 X_train, y_train = smt.fit_sample(X, y)
#       6 np.bincount(y_train)
#
# NameError: name 'SMOTE' is not defined

# %%
skb = SelectKBest(chi2,4)
skb.fit(X,y)
# Get columns to keep
cols = skb.get_support(indices=True)
# Create new dataframe with only desired columns, or overwrite existing
features_df_new = X.iloc[:,cols]
features_df_new
# Out:
#        Agency  Agency Type  Product Name  Destination
# 0           7            1            10           68
# 1           7            1            10           53
# 2           6            1            16           84
# 3           7            1             1           33
# 4           7            1             1           53
# ...       ...          ...           ...          ...
# 52305       2            0             3           75
# 52306      12            0            24           12
# 52307       2            0             9           75
# 52308       7            1            10           84
# 52309       2            0             4           75
#
# [52310 rows x 4 columns]

# %%
X2 = sm.add_constant(X)
est1 = sm.OLS(y,X2)
est2 = smm.fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Claim   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     1866.
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):               0.00
# Time:                        11:59:15   Log-Likelihood:                -18304.
# No. Observations:               52310   AIC:                         3.662e+04
# Df Residuals:                   52304   BIC:                         3.667e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...
